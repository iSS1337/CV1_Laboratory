# %% [markdown]
# <a href="https://colab.research.google.com/github/iSS1337/CV1_Laboratory/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# MASTER PLAN
# Importam datele                               Done
# Verificarea Integritatii datelor              Done
# Impartirea datelor in Train Test [Val]        Done
# Preprocesarea Datelor:                        Not Done
#   * Normalizarea si augumentarea datelor [D]  Not Done
#   * Analiza datelor                           Not Done
#   * Resize                                    Not Done
#   * Hand segmentation                         Not Done
#   * Hand extraction                           Not Done
# Extragem trasaturile                          Not Done
# Clasificare                                   Not Done
# PR curve / Matricea de confuzie               Not Done

# %%
#   Matrice de confuzie pentru un clasificator binar
#
#               1   |  0
#   pred T    100 % |   0
#           ________|_________
#   pred N     0    |  100%
#                   |

# %%
import numpy as np
import matplotlib.pyplot as plt
from glob import glob
import cv2

import random

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
bp = "/content/drive/MyDrive/drive/"

file_path_arr = []
for i in range(4):
  file_path_arr.append(glob(bp+str(i)+"/*.jpg"))
print(len(file_path_arr))
print(file_path_arr)
print(np.shape(file_path_arr))
# Out:
# 4
# [['/content/drive/MyDrive/drive/0/2.jpg', '/content/drive/MyDrive/drive/0/3.jpg', '/content/drive/MyDrive/drive/0/1.jpg', '/content/drive/MyDrive/drive/0/0.jpg', '/content/drive/MyDrive/drive/0/9.jpg', '/content/drive/MyDrive/drive/0/8.jpg', '/content/drive/MyDrive/drive/0/7.jpg', '/content/drive/MyDrive/drive/0/5.jpg', '/content/drive/MyDrive/drive/0/6.jpg', '/content/drive/MyDrive/drive/0/4.jpg'], ['/content/drive/MyDrive/drive/1/3.jpg', '/content/drive/MyDrive/drive/1/4.jpg', '/content/drive/MyDrive/drive/1/2.jpg', '/content/drive/MyDrive/drive/1/1.jpg', '/content/drive/MyDrive/drive/1/0.jpg', '/content/drive/MyDrive/drive/1/9.jpg', '/content/drive/MyDrive/drive/1/8.jpg', '/content/drive/MyDrive/drive/1/7.jpg', '/content/drive/MyDrive/drive/1/6.jpg', '/content/drive/MyDrive/drive/1/5.jpg'], ['/content/drive/MyDrive/drive/2/5.jpg', '/content/drive/MyDrive/drive/2/6.jpg', '/content/drive/MyDrive/drive/2/4.jpg', '/content/drive/MyDrive/drive/2/3.jpg', '/content/drive/MyDrive/drive/2/2.jpg', '/content/drive/MyDrive/drive/2/1.jpg', '/content/drive/MyDrive/drive/2/0.jpg', '/content/drive/MyDrive/drive/2/8.jpg', '/content/drive/MyDrive/drive/2/9.jpg', '/content/drive/MyDrive/drive/2/7.jpg'], ['/content/drive/MyDrive/drive/3/6.jpg', '/content/drive/MyDrive/drive/3/7.jpg', '/content/drive/MyDrive/drive/3/5.jpg', '/content/drive/MyDrive/drive/3/4.jpg', '/content/drive/MyDrive/drive/3/3.jpg', '/content/drive/MyDrive/drive/3/2.jpg', '/content/drive/MyDrive/drive/3/1.jpg', '/content/drive/MyDrive/drive/3/0.jpg', '/content/drive/MyDrive/drive/3/8.jpg', '/content/drive/MyDrive/drive/3/9.jpg']]
# (4, 10)

# %%
random.seed(42)

# %%
image_index_arr = random.sample(range(0,9),7)
print(image_index_arr)
# Out:
# [1, 0, 5, 2, 8, 4, 7]

# %%
train_image_path = []
test_image_path = []

for hand_class in file_path_arr:
  tmp_train = []
  tmp_test = []
  for i in range(10):
    if i not in image_index_arr:
      tmp_test.append(hand_class[i])
    else:
      tmp_train.append(hand_class[i])
  train_image_path.append(tmp_train)
  test_image_path.append(tmp_test)
print(np.shape(train_image_path))
print(np.shape(test_image_path))
# Out:
# (4, 7)
# (4, 3)

# %%
train_images = []
test_images = []

for cls in train_image_path:
  t = []
  for i in cls:
    t.append(cv2.imread(i))
  train_images.append(t)

for cls in test_image_path:
  t = []
  for i in cls:
    t.append(cv2.imread(i))
  test_images.append(t)

print(np.shape(train_images))
print(np.shape(test_images))
# Out:
# (4, 7, 4032, 1908, 3)
# (4, 3, 4032, 1908, 3)

# %%
plt.figure(), plt.imshow(train_images[0][0])
# Out:
# (<Figure size 640x480 with 1 Axes>,
#  <matplotlib.image.AxesImage at 0x7e8b928a2c60>)

# %%
im = train_images[0][0]
img_rgb = cv2.cvtColor(im, cv2.COLOR_BGR2RGB)
plt.figure(), plt.imshow(img_rgb)
# Out:
# (<Figure size 640x480 with 1 Axes>,
#  <matplotlib.image.AxesImage at 0x7e8b928bcc50>)

# %%
print(np.shape(img_rgb))
# Out:
# (4032, 1908, 3)

# %%
def resize_and_covert(image, scale_factor = 10):
  w, h, _ = np.shape(image)
  im_resized = cv2.resize(image, (int(h/scale_factor), int(w/scale_factor)))
  img_rgb = cv2.cvtColor(im_resized, cv2.COLOR_BGR2RGB)
  return img_rgb

# %%
for i,cls in enumerate(train_images):
  for j,im in enumerate(cls):
    train_images[i][j] = resize_and_covert(im)

for i,cls in enumerate(test_images):
  for j,im in enumerate(cls):
    test_images[i][j] = resize_and_covert(im)

# %%
plt.figure(), plt.imshow(train_images[0][0])
# Out:
# (<Figure size 640x480 with 1 Axes>,
#  <matplotlib.image.AxesImage at 0x7e8b84cf9220>)
